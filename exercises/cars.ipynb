# %% [markdown]
# # Data Exploration
#
# In this notebook describe your data exploration steps.

# %% [markdown]
# ## Install dependencies

# %%
# %pip install -r requirements.txt

# %% [markdown]
# ## Load data

# %%
import pandas as pd

df = pd.read_sql_table('cars', 'sqlite:///./cars.sqlite')

# %% [markdown]
# ### Look at the first rows

# %%
df.head(10)
# Out:
#          date    CIN                            name  petrol  diesel   gas
# 0  01.01.2022  01001     Flensburg, kreisfreie Stadt   26809   16230   262  \
# 1  01.01.2022  01002          Kiel, kreisfreie Stadt   71089   35234   713
# 2  01.01.2022  01003        Lübeck, kreisfreie Stadt   66824   30127   800
# 3  01.01.2022  01004    Neumünster, kreisfreie Stadt   26943   14163   317
# 4  01.01.2022  01051         Dithmarschen, Landkreis   48386   32319   518
# 5  01.01.2022  01053  Herzogtum Lauenburg, Landkreis   75300   40192  1035
# 6  01.01.2022  01054        Nordfriesland, Landkreis   60707   41099   600
# 7  01.01.2022  01055          Ostholstein, Landkreis   84081   41358   901
# 8  01.01.2022  01056            Pinneberg, Landkreis  118948   52023  1143
# 9  01.01.2022  01057                 Plön, Landkreis   51167   27522   425
#
#    electro  hybrid  plugInHybrid  others
# 0      741     903           526      17
# 1     1542    2324          1232      20
# ...
